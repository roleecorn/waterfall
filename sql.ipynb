# %%
import sqlite3
import pandas as pd

# %%
status = sqlite3.connect("eddiebauer.db")

# %%
qry = f"SELECT * FROM eddiebauer "
df = pd.read_sql_query(qry, status)
status.close()

# %%
df
# Out:
#                                                 name         imgcode  \
# 0        Women's Favorite Long-Sleeve V-Neck T-Shirt  D0095638_326C1
# 1             Women's Quest Fleece 1/4-Zip - Printed  D0311805_047C1
# 2               Women's Train Ascent Full-Zip Hoodie  D0314520_304C1
# 3                Women's Favorite Long-Sleeve Hoodie  D0093889_481C1
# 4     Women's High Route Grid Fleece Full-Zip Jacket  D0312770_447C1
# ...                                              ...             ...
# 2029              Boys' Cloud Layer 1/4-Zip Pullover  D0130650_804C1
# 2030        Girls' Quest Fleece 1/4-Zip - Colorblock  D0130664_899C1
# 2031             Girls' Quest Fleece 1/4-Zip - Print  D0130665_117C1
# 2032             Boys' Firstline Convertible Ski Bib  D0130473_147C1
# 2033              Girls' Sun Valley Frost Down Parka  D0130226_147C1
#
#       oriprice  price color feature gender   brand  fabric
# 0         30.0   35.0          test  women  nodata  fabric
# ...
